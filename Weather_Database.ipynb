# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import time
from datetime import datetime

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 711

# %%
# Test url for finding description in json
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
city_url = url + "&q=" + "London"
city_weather = requests.get(city_url).json()

# %%
# Find description for city weather
city_weather
# Out:
# {'coord': {'lon': -0.1257, 'lat': 51.5085},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 50.41,
#   'feels_like': 49.39,
#   'temp_min': 48.49,
#   'temp_max': 51.91,
#   'pressure': 1028,
#   'humidity': 90},
#  'visibility': 10000,
#  'wind': {'speed': 12.66, 'deg': 240},
#  'clouds': {'all': 100},
#  'dt': 1643426479,
#  'sys': {'type': 2,
#   'id': 2019646,
#   'country': 'GB',
#   'sunrise': 1643442211,
#   'sunset': 1643474610},
#  'timezone': 0,
#  'id': 2643743,
#  'name': 'London',
#  'cod': 200}

# %%
#Found description
city_weather['weather'][0]['description']
# Out:
# 'overcast clouds'

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# api.openweathermap.org/data/2.5/weather?q={city name}&appid={API key}
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather['weather'][0]['description']
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | vaini
# Processing Record 2 of Set 1 | barrow
# Processing Record 3 of Set 1 | busselton
# Processing Record 4 of Set 1 | merida
# Processing Record 5 of Set 1 | kapaa
# Processing Record 6 of Set 1 | mataura
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | honiara
# Processing Record 9 of Set 1 | bluff
# Processing Record 10 of Set 1 | xucheng
# Processing Record 11 of Set 1 | santa vitoria do palmar
# Processing Record 12 of Set 1 | youkounkoun
# Processing Record 13 of Set 1 | wattegama
# Processing Record 14 of Set 1 | colares
# Processing Record 15 of Set 1 | kirakira
# Processing Record 16 of Set 1 | katsuura
# Processing Record 17 of Set 1 | ushuaia
# Processing Record 18 of Set 1 | sivas
# Processing Record 19 of Set 1 | bengkulu
# Processing Record 20 of Set 1 | nikolskoye
# Processing Record 21 of Set 1 | hamilton
# Processing Record 22 of Set 1 | severo-kurilsk
# Processing Record 23 of Set 1 | guanica
# Processing Record 24 of Set 1 | albany
# Processing Record 25 of Set 1 | kimbe
# Processing Record 26 of Set 1 | namibe
# Processing Record 27 of Set 1 | hithadhoo
# Processing Record 28 of Set 1 | tulagi
# Processing Record 29 of Set 1 | skelleftea
# Processing Record 30 of Set 1 | ambodifototra
# City not found. Skipping...
# Processing Record 31 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 32 of Set 1 | byron bay
# Processing Record 33 of Set 1 | qaanaaq
# Processing Record 34 of Set 1 | kamareddi
# Processing Record 35 of Set 1 | ewa beach
# Processing Record 36 of Set 1 | punta arenas
# Processing Record 37 of Set 1 | mar del plata
# Processing Record 38 of Set 1 | kozhva
# Processing Record 39 of Set 1 | mullaitivu
# City not found. Skipping...
# Processing Record 40 of Set 1 | ponta do sol
# Processing Record 41 of Set 1 | cape town
# Processing Record 42 of Set 1 | arraial do cabo
# Processing Record 43 of Set 1 | zunyi
# Processing Record 44 of Set 1 | hobart
# Processing Record 45 of Set 1 | victoria
# Processing Record 46 of Set 1 | filingue
# Processing Record 47 of Set 1 | westport
# Processing Record 48 of Set 1 | grand gaube
# Processing Record 49 of Set 1 | axim
# Processing Record 50 of Set 1 | bredasdorp
# Processing Record 1 of Set 2 | lebu
# Processing Record 2 of Set 2 | castro
# Processing Record 3 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 4 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 2 | hermanus
# Processing Record 6 of Set 2 | san quintin
# Processing Record 7 of Set 2 | izazi
# Processing Record 8 of Set 2 | yellowknife
# Processing Record 9 of Set 2 | te anau
# Processing Record 10 of Set 2 | tuktoyaktuk
# Processing Record 11 of Set 2 | dmitrovsk-orlovskiy
# Processing Record 12 of Set 2 | vestmanna
# Processing Record 13 of Set 2 | new norfolk
# Processing Record 14 of Set 2 | butaritari
# Processing Record 15 of Set 2 | tiksi
# Processing Record 16 of Set 2 | saskylakh
# Processing Record 17 of Set 2 | jamestown
# Processing Record 18 of Set 2 | chuy
# Processing Record 19 of Set 2 | umba
# Processing Record 20 of Set 2 | lakes entrance
# Processing Record 21 of Set 2 | abu samrah
# Processing Record 22 of Set 2 | kuching
# Processing Record 23 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 24 of Set 2 | thompson
# Processing Record 25 of Set 2 | chokurdakh
# Processing Record 26 of Set 2 | kodiak
# Processing Record 27 of Set 2 | fort saint james
# Processing Record 28 of Set 2 | kashi
# Processing Record 29 of Set 2 | pozo colorado
# Processing Record 30 of Set 2 | dikson
# Processing Record 31 of Set 2 | yarada
# Processing Record 32 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 33 of Set 2 | longyearbyen
# Processing Record 34 of Set 2 | dunedin
# Processing Record 35 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 36 of Set 2 | muros
# Processing Record 37 of Set 2 | portland
# Processing Record 38 of Set 2 | saint-philippe
# Processing Record 39 of Set 2 | olbia
# Processing Record 40 of Set 2 | atuona
# Processing Record 41 of Set 2 | coromandel
# Processing Record 42 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 43 of Set 2 | kangaatsiaq
# Processing Record 44 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 45 of Set 2 | alofi
# Processing Record 46 of Set 2 | jeremie
# Processing Record 47 of Set 2 | mehran
# Processing Record 48 of Set 2 | vanimo
# Processing Record 49 of Set 2 | upernavik
# Processing Record 50 of Set 2 | chernyshevskiy
# Processing Record 1 of Set 3 | mahon
# Processing Record 2 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 3 of Set 3 | khatanga
# Processing Record 4 of Set 3 | mahebourg
# Processing Record 5 of Set 3 | kruisfontein
# Processing Record 6 of Set 3 | port lincoln
# Processing Record 7 of Set 3 | ocampo
# Processing Record 8 of Set 3 | sabang
# Processing Record 9 of Set 3 | waingapu
# Processing Record 10 of Set 3 | borlange
# City not found. Skipping...
# Processing Record 11 of Set 3 | pevek
# Processing Record 12 of Set 3 | tidore
# City not found. Skipping...
# Processing Record 13 of Set 3 | nabire
# Processing Record 14 of Set 3 | puerto colombia
# Processing Record 15 of Set 3 | carauari
# Processing Record 16 of Set 3 | jesup
# Processing Record 17 of Set 3 | preobrazheniye
# Processing Record 18 of Set 3 | saint george
# Processing Record 19 of Set 3 | ballstad
# City not found. Skipping...
# Processing Record 20 of Set 3 | tasiilaq
# Processing Record 21 of Set 3 | santa isabel
# Processing Record 22 of Set 3 | cherskiy
# Processing Record 23 of Set 3 | lasa
# Processing Record 24 of Set 3 | meyungs
# City not found. Skipping...
# Processing Record 25 of Set 3 | ranong
# Processing Record 26 of Set 3 | kichera
# Processing Record 27 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 28 of Set 3 | cabedelo
# Processing Record 29 of Set 3 | sosnytsya
# Processing Record 30 of Set 3 | poum
# Processing Record 31 of Set 3 | ojinaga
# Processing Record 32 of Set 3 | bambous virieux
# Processing Record 33 of Set 3 | rancagua
# Processing Record 34 of Set 3 | balsas
# Processing Record 35 of Set 3 | ponta delgada
# Processing Record 36 of Set 3 | pisco
# Processing Record 37 of Set 3 | lagoa
# Processing Record 38 of Set 3 | provideniya
# Processing Record 39 of Set 3 | port alfred
# Processing Record 40 of Set 3 | kon tum
# Processing Record 41 of Set 3 | puerto del rosario
# Processing Record 42 of Set 3 | amapa
# Processing Record 43 of Set 3 | ferrol
# Processing Record 44 of Set 3 | kedrovyy
# Processing Record 45 of Set 3 | aklavik
# Processing Record 46 of Set 3 | tyazhinskiy
# Processing Record 47 of Set 3 | narsaq
# Processing Record 48 of Set 3 | danielskuil
# Processing Record 49 of Set 3 | ribeira grande
# Processing Record 50 of Set 3 | sao filipe
# Processing Record 1 of Set 4 | yerbogachen
# Processing Record 2 of Set 4 | chilca
# Processing Record 3 of Set 4 | leningradskiy
# Processing Record 4 of Set 4 | palmer
# Processing Record 5 of Set 4 | vila franca do campo
# Processing Record 6 of Set 4 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 7 of Set 4 | kununurra
# Processing Record 8 of Set 4 | junin
# Processing Record 9 of Set 4 | berlevag
# Processing Record 10 of Set 4 | virginia beach
# Processing Record 11 of Set 4 | hami
# Processing Record 12 of Set 4 | san vicente
# Processing Record 13 of Set 4 | ancud
# Processing Record 14 of Set 4 | zheleznodorozhnyy
# Processing Record 15 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 16 of Set 4 | hilo
# Processing Record 17 of Set 4 | fare
# Processing Record 18 of Set 4 | georgetown
# Processing Record 19 of Set 4 | basco
# Processing Record 20 of Set 4 | lichuan
# Processing Record 21 of Set 4 | laguna
# Processing Record 22 of Set 4 | goderich
# Processing Record 23 of Set 4 | tamboril
# Processing Record 24 of Set 4 | tabuk
# Processing Record 25 of Set 4 | yurya
# City not found. Skipping...
# Processing Record 26 of Set 4 | mutsamudu
# City not found. Skipping...
# Processing Record 27 of Set 4 | hamina
# Processing Record 28 of Set 4 | bathsheba
# Processing Record 29 of Set 4 | ishigaki
# Processing Record 30 of Set 4 | avarua
# Processing Record 31 of Set 4 | paragominas
# Processing Record 32 of Set 4 | kodinsk
# Processing Record 33 of Set 4 | karasjok
# Processing Record 34 of Set 4 | taguatinga
# Processing Record 35 of Set 4 | suhut
# Processing Record 36 of Set 4 | carutapera
# Processing Record 37 of Set 4 | tateyama
# Processing Record 38 of Set 4 | beloha
# Processing Record 39 of Set 4 | itaituba
# Processing Record 40 of Set 4 | jiangyou
# Processing Record 41 of Set 4 | morgan city
# Processing Record 42 of Set 4 | gat
# Processing Record 43 of Set 4 | waw
# Processing Record 44 of Set 4 | sandavagur
# City not found. Skipping...
# Processing Record 45 of Set 4 | coahuayana
# Processing Record 46 of Set 4 | iberia
# Processing Record 47 of Set 4 | iqaluit
# Processing Record 48 of Set 4 | sisimiut
# Processing Record 49 of Set 4 | tuggurt
# City not found. Skipping...
# Processing Record 50 of Set 4 | christchurch
# Processing Record 1 of Set 5 | ust-nera
# Processing Record 2 of Set 5 | dalvik
# Processing Record 3 of Set 5 | havoysund
# Processing Record 4 of Set 5 | novopetrovskoye
# Processing Record 5 of Set 5 | carnarvon
# Processing Record 6 of Set 5 | zhob
# Processing Record 7 of Set 5 | kaitangata
# Processing Record 8 of Set 5 | barkhan
# Processing Record 9 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 10 of Set 5 | launceston
# Processing Record 11 of Set 5 | rosetta
# Processing Record 12 of Set 5 | sorong
# Processing Record 13 of Set 5 | college
# Processing Record 14 of Set 5 | urumqi
# Processing Record 15 of Set 5 | teguise
# Processing Record 16 of Set 5 | airai
# Processing Record 17 of Set 5 | zhangye
# Processing Record 18 of Set 5 | talnakh
# Processing Record 19 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 20 of Set 5 | vila velha
# Processing Record 21 of Set 5 | alice springs
# Processing Record 22 of Set 5 | visnes
# Processing Record 23 of Set 5 | zinder
# Processing Record 24 of Set 5 | hualmay
# Processing Record 25 of Set 5 | cockburn harbour
# City not found. Skipping...
# Processing Record 26 of Set 5 | saint-pierre
# Processing Record 27 of Set 5 | salalah
# Processing Record 28 of Set 5 | timiryazevskiy
# Processing Record 29 of Set 5 | barcelona
# Processing Record 30 of Set 5 | kandi
# Processing Record 31 of Set 5 | adrar
# Processing Record 32 of Set 5 | hyeres
# Processing Record 33 of Set 5 | rio bravo
# Processing Record 34 of Set 5 | abonnema
# Processing Record 35 of Set 5 | lorengau
# Processing Record 36 of Set 5 | dwarka
# Processing Record 37 of Set 5 | meulaboh
# Processing Record 38 of Set 5 | tuatapere
# Processing Record 39 of Set 5 | thunder bay
# Processing Record 40 of Set 5 | ilulissat
# Processing Record 41 of Set 5 | duvan
# Processing Record 42 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 43 of Set 5 | san cristobal
# Processing Record 44 of Set 5 | cirebon
# Processing Record 45 of Set 5 | la libertad
# Processing Record 46 of Set 5 | sur
# Processing Record 47 of Set 5 | kajaani
# Processing Record 48 of Set 5 | yenagoa
# Processing Record 49 of Set 5 | kemijarvi
# Processing Record 50 of Set 5 | yumen
# Processing Record 1 of Set 6 | jawhar
# Processing Record 2 of Set 6 | capivari
# Processing Record 3 of Set 6 | rawson
# Processing Record 4 of Set 6 | strezhevoy
# Processing Record 5 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 6 of Set 6 | goundam
# Processing Record 7 of Set 6 | quelimane
# Processing Record 8 of Set 6 | douentza
# Processing Record 9 of Set 6 | klaksvik
# Processing Record 10 of Set 6 | narrabri
# Processing Record 11 of Set 6 | mount isa
# Processing Record 12 of Set 6 | port augusta
# Processing Record 13 of Set 6 | margate
# Processing Record 14 of Set 6 | broome
# Processing Record 15 of Set 6 | fortuna
# Processing Record 16 of Set 6 | smolenka
# Processing Record 17 of Set 6 | egvekinot
# Processing Record 18 of Set 6 | scottsbluff
# Processing Record 19 of Set 6 | lengshuitan
# Processing Record 20 of Set 6 | shenjiamen
# Processing Record 21 of Set 6 | ixtapa
# Processing Record 22 of Set 6 | tasbuget
# City not found. Skipping...
# Processing Record 23 of Set 6 | souillac
# Processing Record 24 of Set 6 | sacadat
# Processing Record 25 of Set 6 | dingle
# Processing Record 26 of Set 6 | rawannawi
# City not found. Skipping...
# Processing Record 27 of Set 6 | grindavik
# Processing Record 28 of Set 6 | anadyr
# Processing Record 29 of Set 6 | port macquarie
# Processing Record 30 of Set 6 | salur
# Processing Record 31 of Set 6 | sandane
# Processing Record 32 of Set 6 | tessalit
# Processing Record 33 of Set 6 | inirida
# Processing Record 34 of Set 6 | alta floresta
# Processing Record 35 of Set 6 | puerto ayora
# Processing Record 36 of Set 6 | acapulco
# Processing Record 37 of Set 6 | adilabad
# Processing Record 38 of Set 6 | bara
# Processing Record 39 of Set 6 | derzhavinsk
# Processing Record 40 of Set 6 | cariamanga
# Processing Record 41 of Set 6 | vardo
# Processing Record 42 of Set 6 | labuhan
# Processing Record 43 of Set 6 | bokspits
# City not found. Skipping...
# Processing Record 44 of Set 6 | paengaroa
# Processing Record 45 of Set 6 | miri
# Processing Record 46 of Set 6 | nouadhibou
# Processing Record 47 of Set 6 | lavrentiya
# Processing Record 48 of Set 6 | tual
# Processing Record 49 of Set 6 | codrington
# Processing Record 50 of Set 6 | mitsamiouli
# Processing Record 1 of Set 7 | broken hill
# Processing Record 2 of Set 7 | kunashak
# Processing Record 3 of Set 7 | sioux lookout
# Processing Record 4 of Set 7 | charters towers
# Processing Record 5 of Set 7 | badovinci
# Processing Record 6 of Set 7 | vostok
# Processing Record 7 of Set 7 | ambilobe
# Processing Record 8 of Set 7 | shirgaon
# Processing Record 9 of Set 7 | mount gambier
# Processing Record 10 of Set 7 | touros
# Processing Record 11 of Set 7 | camacha
# Processing Record 12 of Set 7 | wulanhaote
# City not found. Skipping...
# Processing Record 13 of Set 7 | longlac
# City not found. Skipping...
# Processing Record 14 of Set 7 | puerto santander
# Processing Record 15 of Set 7 | tagusao
# Processing Record 16 of Set 7 | qaqortoq
# Processing Record 17 of Set 7 | san patricio
# Processing Record 18 of Set 7 | vila do maio
# Processing Record 19 of Set 7 | katangli
# Processing Record 20 of Set 7 | lutin
# Processing Record 21 of Set 7 | pinotepa nacional
# Processing Record 22 of Set 7 | isangel
# Processing Record 23 of Set 7 | sagua de tanamo
# Processing Record 24 of Set 7 | bathurst
# Processing Record 25 of Set 7 | katherine
# Processing Record 26 of Set 7 | strathmiglo
# Processing Record 27 of Set 7 | ca mau
# Processing Record 28 of Set 7 | saint-augustin
# Processing Record 29 of Set 7 | tromso
# Processing Record 30 of Set 7 | zhigansk
# Processing Record 31 of Set 7 | calbuco
# Processing Record 32 of Set 7 | cidreira
# Processing Record 33 of Set 7 | sebina
# Processing Record 34 of Set 7 | kiunga
# Processing Record 35 of Set 7 | dauriya
# Processing Record 36 of Set 7 | acajutla
# Processing Record 37 of Set 7 | coari
# Processing Record 38 of Set 7 | danville
# Processing Record 39 of Set 7 | hasaki
# Processing Record 40 of Set 7 | faanui
# Processing Record 41 of Set 7 | stillwater
# Processing Record 42 of Set 7 | puerto leguizamo
# Processing Record 43 of Set 7 | galesong
# Processing Record 44 of Set 7 | pochutla
# Processing Record 45 of Set 7 | yangambi
# Processing Record 46 of Set 7 | dawei
# Processing Record 47 of Set 7 | lalpur
# Processing Record 48 of Set 7 | kudat
# Processing Record 49 of Set 7 | ransang
# Processing Record 50 of Set 7 | comodoro rivadavia
# Processing Record 1 of Set 8 | lalganj
# Processing Record 2 of Set 8 | katrineholm
# Processing Record 3 of Set 8 | agirish
# Processing Record 4 of Set 8 | clyde river
# Processing Record 5 of Set 8 | east london
# Processing Record 6 of Set 8 | vao
# Processing Record 7 of Set 8 | tucuma
# Processing Record 8 of Set 8 | mogadishu
# Processing Record 9 of Set 8 | maturin
# Processing Record 10 of Set 8 | chandur
# Processing Record 11 of Set 8 | lashio
# Processing Record 12 of Set 8 | xuddur
# Processing Record 13 of Set 8 | acari
# Processing Record 14 of Set 8 | key west
# Processing Record 15 of Set 8 | namatanai
# Processing Record 16 of Set 8 | port elizabeth
# Processing Record 17 of Set 8 | riyadh
# Processing Record 18 of Set 8 | esperance
# Processing Record 19 of Set 8 | pangnirtung
# Processing Record 20 of Set 8 | bowen
# Processing Record 21 of Set 8 | luancheng
# Processing Record 22 of Set 8 | ruatoria
# City not found. Skipping...
# Processing Record 23 of Set 8 | nioki
# Processing Record 24 of Set 8 | richards bay
# Processing Record 25 of Set 8 | suozhen
# Processing Record 26 of Set 8 | port-gentil
# Processing Record 27 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 28 of Set 8 | hambantota
# Processing Record 29 of Set 8 | klyuchi
# Processing Record 30 of Set 8 | zhangjiakou
# Processing Record 31 of Set 8 | lugazi
# Processing Record 32 of Set 8 | valleyview
# Processing Record 33 of Set 8 | araguacu
# Processing Record 34 of Set 8 | xining
# Processing Record 35 of Set 8 | gejiu
# Processing Record 36 of Set 8 | newton
# Processing Record 37 of Set 8 | trincomalee
# Processing Record 38 of Set 8 | port hardy
# Processing Record 39 of Set 8 | agadir
# Processing Record 40 of Set 8 | cheyenne
# Processing Record 41 of Set 8 | gushikawa
# Processing Record 42 of Set 8 | inderborskiy
# City not found. Skipping...
# Processing Record 43 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 44 of Set 8 | geraldton
# Processing Record 45 of Set 8 | bayonet point
# Processing Record 46 of Set 8 | bethel
# Processing Record 47 of Set 8 | norman wells
# Processing Record 48 of Set 8 | pokhara
# Processing Record 49 of Set 8 | ritchie
# Processing Record 50 of Set 8 | nadym
# Processing Record 1 of Set 9 | west wendover
# Processing Record 2 of Set 9 | cabo san lucas
# Processing Record 3 of Set 9 | tarudant
# City not found. Skipping...
# Processing Record 4 of Set 9 | tautira
# Processing Record 5 of Set 9 | wewak
# Processing Record 6 of Set 9 | ostrovnoy
# Processing Record 7 of Set 9 | faya
# Processing Record 8 of Set 9 | ukiah
# Processing Record 9 of Set 9 | miyako
# Processing Record 10 of Set 9 | kishi
# Processing Record 11 of Set 9 | oda
# Processing Record 12 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 13 of Set 9 | uvalde
# Processing Record 14 of Set 9 | missoula
# Processing Record 15 of Set 9 | santarem
# Processing Record 16 of Set 9 | shubarshi
# Processing Record 17 of Set 9 | paamiut
# Processing Record 18 of Set 9 | havre-saint-pierre
# Processing Record 19 of Set 9 | codo
# Processing Record 20 of Set 9 | beringovskiy
# Processing Record 21 of Set 9 | sao joao da barra
# Processing Record 22 of Set 9 | uyemskiy
# Processing Record 23 of Set 9 | waipawa
# Processing Record 24 of Set 9 | alotau
# City not found. Skipping...
# Processing Record 25 of Set 9 | presidente medici
# Processing Record 26 of Set 9 | inawashiro
# Processing Record 27 of Set 9 | fort nelson
# Processing Record 28 of Set 9 | sept-iles
# Processing Record 29 of Set 9 | komsomolskiy
# Processing Record 30 of Set 9 | chicama
# Processing Record 31 of Set 9 | port hedland
# Processing Record 32 of Set 9 | saint quentin
# City not found. Skipping...
# Processing Record 33 of Set 9 | baiyin
# Processing Record 34 of Set 9 | champerico
# Processing Record 35 of Set 9 | soyo
# Processing Record 36 of Set 9 | fort frances
# Processing Record 37 of Set 9 | severobaykalsk
# Processing Record 38 of Set 9 | khuzhir
# Processing Record 39 of Set 9 | prizren
# Processing Record 40 of Set 9 | pangkalanbuun
# Processing Record 41 of Set 9 | magadi
# Processing Record 42 of Set 9 | katsina
# Processing Record 43 of Set 9 | bangkalan
# Processing Record 44 of Set 9 | goure
# Processing Record 45 of Set 9 | afgoye
# City not found. Skipping...
# Processing Record 46 of Set 9 | emiliano zapata
# Processing Record 47 of Set 9 | bay city
# Processing Record 48 of Set 9 | talara
# Processing Record 49 of Set 9 | shache
# Processing Record 50 of Set 9 | mergui
# City not found. Skipping...
# Processing Record 1 of Set 10 | henties bay
# Processing Record 2 of Set 10 | luanda
# Processing Record 3 of Set 10 | andenes
# Processing Record 4 of Set 10 | coquimbo
# Processing Record 5 of Set 10 | tecoanapa
# Processing Record 6 of Set 10 | tricase
# Processing Record 7 of Set 10 | janakkala
# Processing Record 8 of Set 10 | tura
# Processing Record 9 of Set 10 | saquarema
# Processing Record 10 of Set 10 | matamoros
# Processing Record 11 of Set 10 | tambura
# Processing Record 12 of Set 10 | tamandare
# Processing Record 13 of Set 10 | dolgorukovo
# Processing Record 14 of Set 10 | nizhnevartovsk
# Processing Record 15 of Set 10 | luganville
# Processing Record 16 of Set 10 | puri
# Processing Record 17 of Set 10 | kaniama
# Processing Record 18 of Set 10 | haines junction
# Processing Record 19 of Set 10 | malinyi
# Processing Record 20 of Set 10 | cahokia
# Processing Record 21 of Set 10 | masvingo
# Processing Record 22 of Set 10 | ribeira brava
# Processing Record 23 of Set 10 | awjilah
# Processing Record 24 of Set 10 | naron
# Processing Record 25 of Set 10 | cumpas
# Processing Record 26 of Set 10 | qandahar
# City not found. Skipping...
# Processing Record 27 of Set 10 | huangnihe
# Processing Record 28 of Set 10 | mwinilunga
# Processing Record 29 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 30 of Set 10 | samana
# Processing Record 31 of Set 10 | caravelas
# Processing Record 32 of Set 10 | iskateley
# Processing Record 33 of Set 10 | viedma
# Processing Record 34 of Set 10 | diego de almagro
# Processing Record 35 of Set 10 | maceio
# Processing Record 36 of Set 10 | buraydah
# Processing Record 37 of Set 10 | oranjestad
# Processing Record 38 of Set 10 | severo-yeniseyskiy
# Processing Record 39 of Set 10 | kaeo
# Processing Record 40 of Set 10 | coihaique
# Processing Record 41 of Set 10 | reconquista
# Processing Record 42 of Set 10 | praia da vitoria
# Processing Record 43 of Set 10 | bantou
# Processing Record 44 of Set 10 | wexford
# Processing Record 45 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 46 of Set 10 | cap-aux-meules
# Processing Record 47 of Set 10 | kavaratti
# Processing Record 48 of Set 10 | tucumcari
# Processing Record 49 of Set 10 | itarema
# Processing Record 50 of Set 10 | ahipara
# Processing Record 1 of Set 11 | harindanga
# Processing Record 2 of Set 11 | meihekou
# Processing Record 3 of Set 11 | naze
# Processing Record 4 of Set 11 | imbituba
# Processing Record 5 of Set 11 | honningsvag
# Processing Record 6 of Set 11 | hovd
# Processing Record 7 of Set 11 | constitucion
# Processing Record 8 of Set 11 | tongliao
# Processing Record 9 of Set 11 | san carlos de bariloche
# Processing Record 10 of Set 11 | kamenka
# Processing Record 11 of Set 11 | malpe
# Processing Record 12 of Set 11 | rosarito
# Processing Record 13 of Set 11 | deputatskiy
# Processing Record 14 of Set 11 | tupik
# Processing Record 15 of Set 11 | raton
# Processing Record 16 of Set 11 | chara
# Processing Record 17 of Set 11 | sangar
# Processing Record 18 of Set 11 | bur gabo
# City not found. Skipping...
# Processing Record 19 of Set 11 | lincoln
# Processing Record 20 of Set 11 | kropotkin
# Processing Record 21 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 22 of Set 11 | tiznit
# Processing Record 23 of Set 11 | tevaitoa
# Processing Record 24 of Set 11 | kavieng
# Processing Record 25 of Set 11 | bundaberg
# Processing Record 26 of Set 11 | plastun
# Processing Record 27 of Set 11 | vestmannaeyjar
# Processing Record 28 of Set 11 | zeya
# Processing Record 29 of Set 11 | muyezerskiy
# Processing Record 30 of Set 11 | marienburg
# Processing Record 31 of Set 11 | lomovka
# Processing Record 32 of Set 11 | buta
# Processing Record 33 of Set 11 | impfondo
# Processing Record 34 of Set 11 | parati
# Processing Record 35 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 36 of Set 11 | omboue
# Processing Record 37 of Set 11 | boulder city
# Processing Record 38 of Set 11 | trogir
# Processing Record 39 of Set 11 | barbar
# City not found. Skipping...
# Processing Record 40 of Set 11 | torbay
# Processing Record 41 of Set 11 | cleethorpes
# Processing Record 42 of Set 11 | bubaque
# Processing Record 43 of Set 11 | lehigh acres
# Processing Record 44 of Set 11 | altay
# Processing Record 45 of Set 11 | saint-francois
# Processing Record 46 of Set 11 | jabiru
# City not found. Skipping...
# Processing Record 47 of Set 11 | zhaotong
# Processing Record 48 of Set 11 | chusovoy
# Processing Record 49 of Set 11 | allanmyo
# City not found. Skipping...
# Processing Record 50 of Set 11 | panzhihua
# Processing Record 1 of Set 12 | cockburn town
# Processing Record 2 of Set 12 | dhidhdhoo
# Processing Record 3 of Set 12 | piranhas
# Processing Record 4 of Set 12 | padang
# Processing Record 5 of Set 12 | birao
# Processing Record 6 of Set 12 | huarmey
# Processing Record 7 of Set 12 | zhucheng
# Processing Record 8 of Set 12 | saint-leu
# Processing Record 9 of Set 12 | husavik
# Processing Record 10 of Set 12 | amahai
# Processing Record 11 of Set 12 | picton
# Processing Record 12 of Set 12 | rimbey
# Processing Record 13 of Set 12 | bolshaya chernigovka
# City not found. Skipping...
# Processing Record 14 of Set 12 | luderitz
# Processing Record 15 of Set 12 | khanewal
# Processing Record 16 of Set 12 | yar-sale
# Processing Record 17 of Set 12 | kathmandu
# Processing Record 18 of Set 12 | satitoa
# City not found. Skipping...
# Processing Record 19 of Set 12 | grants
# Processing Record 20 of Set 12 | northam
# Processing Record 21 of Set 12 | tharrawaddy
# City not found. Skipping...
# Processing Record 22 of Set 12 | santiago del estero
# Processing Record 23 of Set 12 | port hawkesbury
# Processing Record 24 of Set 12 | dalinghe
# City not found. Skipping...
# Processing Record 25 of Set 12 | oron
# Processing Record 26 of Set 12 | pirenopolis
# Processing Record 27 of Set 12 | matay
# Processing Record 28 of Set 12 | lewisville
# Processing Record 29 of Set 12 | nemuro
# Processing Record 30 of Set 12 | tibasosa
# Processing Record 31 of Set 12 | kahului
# Processing Record 32 of Set 12 | ximei
# Processing Record 33 of Set 12 | camana
# Processing Record 34 of Set 12 | usinsk
# Processing Record 35 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 36 of Set 12 | verkh-usugli
# Processing Record 37 of Set 12 | rantepao
# Processing Record 38 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 39 of Set 12 | fatsa
# Processing Record 40 of Set 12 | tahlequah
# Processing Record 41 of Set 12 | kefamenanu
# Processing Record 42 of Set 12 | zacatepec
# Processing Record 43 of Set 12 | fukuma
# Processing Record 44 of Set 12 | mosquera
# Processing Record 45 of Set 12 | sistranda
# Processing Record 46 of Set 12 | yomitan
# City not found. Skipping...
# Processing Record 47 of Set 12 | hofn
# Processing Record 48 of Set 12 | thinadhoo
# Processing Record 49 of Set 12 | muisne
# Processing Record 50 of Set 12 | dukat
# Processing Record 1 of Set 13 | gilbues
# Processing Record 2 of Set 13 | kandrian
# Processing Record 3 of Set 13 | hukuntsi
# Processing Record 4 of Set 13 | svetlaya
# Processing Record 5 of Set 13 | codroipo
# Processing Record 6 of Set 13 | nanortalik
# Processing Record 7 of Set 13 | rochegda
# Processing Record 8 of Set 13 | nova olimpia
# Processing Record 9 of Set 13 | auki
# Processing Record 10 of Set 13 | peniche
# Processing Record 11 of Set 13 | akdepe
# Processing Record 12 of Set 13 | koshurnikovo
# Processing Record 13 of Set 13 | khasan
# Processing Record 14 of Set 13 | roebourne
# Processing Record 15 of Set 13 | bardiyah
# Processing Record 16 of Set 13 | bani
# Processing Record 17 of Set 13 | zhaodong
# Processing Record 18 of Set 13 | morondava
# Processing Record 19 of Set 13 | ust-tsilma
# Processing Record 20 of Set 13 | whitehorse
# Processing Record 21 of Set 13 | marsh harbour
# Processing Record 22 of Set 13 | dzhusaly
# City not found. Skipping...
# Processing Record 23 of Set 13 | cap malheureux
# Processing Record 24 of Set 13 | los llanos de aridane
# Processing Record 25 of Set 13 | ciudad bolivar
# Processing Record 26 of Set 13 | sterling
# Processing Record 27 of Set 13 | kieta
# Processing Record 28 of Set 13 | galeana
# Processing Record 29 of Set 13 | conceicao do araguaia
# Processing Record 30 of Set 13 | sinnamary
# Processing Record 31 of Set 13 | stoyba
# City not found. Skipping...
# Processing Record 32 of Set 13 | hidalgo
# Processing Record 33 of Set 13 | sola
# Processing Record 34 of Set 13 | loa janan
# Processing Record 35 of Set 13 | mayumba
# Processing Record 36 of Set 13 | linhares
# Processing Record 37 of Set 13 | mandalgovi
# Processing Record 38 of Set 13 | leninsk
# Processing Record 39 of Set 13 | yarega
# Processing Record 40 of Set 13 | athabasca
# Processing Record 41 of Set 13 | port pirie
# Processing Record 42 of Set 13 | abu kamal
# Processing Record 43 of Set 13 | barrhead
# Processing Record 44 of Set 13 | safranbolu
# Processing Record 45 of Set 13 | tabou
# Processing Record 46 of Set 13 | khandyga
# Processing Record 47 of Set 13 | abu dhabi
# Processing Record 48 of Set 13 | kollam
# Processing Record 49 of Set 13 | santa cruz de la palma
# Processing Record 50 of Set 13 | mancio lima
# Processing Record 1 of Set 14 | acuna
# City not found. Skipping...
# Processing Record 2 of Set 14 | pokaran
# Processing Record 3 of Set 14 | edea
# Processing Record 4 of Set 14 | williston
# Processing Record 5 of Set 14 | ust-koksa
# Processing Record 6 of Set 14 | almaznyy
# Processing Record 7 of Set 14 | banamba
# Processing Record 8 of Set 14 | gangotri
# City not found. Skipping...
# Processing Record 9 of Set 14 | storforshei
# Processing Record 10 of Set 14 | atar
# Processing Record 11 of Set 14 | yulara
# Processing Record 12 of Set 14 | umm lajj
# Processing Record 13 of Set 14 | atyrau
# Processing Record 14 of Set 14 | la romana
# Processing Record 15 of Set 14 | banikoara
# Processing Record 16 of Set 14 | nha trang
# Processing Record 17 of Set 14 | tommot
# Processing Record 18 of Set 14 | tongzhou
# Processing Record 19 of Set 14 | zaysan
# Processing Record 20 of Set 14 | fort smith
# Processing Record 21 of Set 14 | jerome
# Processing Record 22 of Set 14 | rosario oeste
# Processing Record 23 of Set 14 | yarmouth
# Processing Record 24 of Set 14 | ahome
# Processing Record 25 of Set 14 | tupiza
# Processing Record 26 of Set 14 | lensk
# Processing Record 27 of Set 14 | troitsko-pechorsk
# Processing Record 28 of Set 14 | lima
# Processing Record 29 of Set 14 | mococa
# Processing Record 30 of Set 14 | rio grande
# Processing Record 31 of Set 14 | tezu
# Processing Record 32 of Set 14 | ndele
# Processing Record 33 of Set 14 | tsienyane
# City not found. Skipping...
# Processing Record 34 of Set 14 | jalu
# Processing Record 35 of Set 14 | harbour breton
# Processing Record 36 of Set 14 | nantucket
# Processing Record 37 of Set 14 | coruripe
# Processing Record 38 of Set 14 | manapa
# Processing Record 39 of Set 14 | khromtau
# Processing Record 40 of Set 14 | palmerston
# Processing Record 41 of Set 14 | baoro
# Processing Record 42 of Set 14 | barra do bugres
# Processing Record 43 of Set 14 | kaspiyskiy
# Processing Record 44 of Set 14 | fomboni
# Processing Record 45 of Set 14 | wageningen
# Processing Record 46 of Set 14 | aksu
# Processing Record 47 of Set 14 | kegayli
# City not found. Skipping...
# Processing Record 48 of Set 14 | dandong
# Processing Record 49 of Set 14 | bariadi
# Processing Record 50 of Set 14 | aklera
# Processing Record 1 of Set 15 | dong hoi
# Processing Record 2 of Set 15 | cedar city
# Processing Record 3 of Set 15 | mao
# Processing Record 4 of Set 15 | igrim
# Processing Record 5 of Set 15 | hailar
# Processing Record 6 of Set 15 | kalomo
# City not found. Skipping...
# Processing Record 7 of Set 15 | biltine
# Processing Record 8 of Set 15 | micoud
# Processing Record 9 of Set 15 | brae
# Processing Record 10 of Set 15 | antofagasta
# Processing Record 11 of Set 15 | mentok
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#         City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Vaini      TO -21.2000 -175.2000     82.78        78         100
# 1     Barrow      US  71.2906 -156.7887     -5.78        77         100
# 2  Busselton      AU -33.6500  115.3333     95.04        41          98
# 3     Merida      MX  20.9667  -89.6167     73.02        68          75
# 4      Kapaa      US  22.0752 -159.3190     78.78        70           0
# 5    Mataura      NZ -46.1927  168.8643     66.47        22          88
# 6    Rikitea      PF -23.1203 -134.9692     78.03        71          90
# 7    Honiara      SB  -9.4333  159.9500     82.98        73         100
# 8      Bluff      NZ -46.6000  168.3333     66.79        60          92
# 9    Xucheng      CN  20.3500  110.1288     74.10        74          50
#
#    Wind Speed Current Description
# 0       17.07     overcast clouds
# 1       17.27     overcast clouds
# 2        5.79     overcast clouds
# 3       20.71       broken clouds
# 4        1.01           clear sky
# 5        8.19     overcast clouds
# 6       13.89     overcast clouds
# 7        6.02     overcast clouds
# 8        8.95     overcast clouds
# 9       14.81    scattered clouds

# %%
city_data_df.to_csv('Weather_Database/WeatherPy_Database.csv')
